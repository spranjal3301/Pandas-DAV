# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Computing Descriptive Statistics

# %%
# List of Tuples
empSalary = [('jack', 2000, 2010, 2050, 2134, 2111),
             ('Riti', 3000, 3022, 3456, 3111, 2109),
             ('Aadi', 4022, np.NaN, 2077, 2134, 3122),
             ('Mohit', 3012, 3050, 2010, 2122, 1111),
             ('Veena', 2023, 2232, np.NaN, 2112, 1099),
             ('Shaun', 2123, 2510, 3050, 3134, 2122),
             ('Mark', 4000, 2000, 2050, 2122, 2111)
             ]

# %%
emp_salary_df = pd.DataFrame(empSalary)
emp_salary_df
# Out:
#        0     1       2       3     4     5
# 0   jack  2000  2010.0  2050.0  2134  2111
# 1   Riti  3000  3022.0  3456.0  3111  2109
# 2   Aadi  4022     NaN  2077.0  2134  3122
# 3  Mohit  3012  3050.0  2010.0  2122  1111
# 4  Veena  2023  2232.0     NaN  2112  1099
# 5  Shaun  2123  2510.0  3050.0  3134  2122
# 6   Mark  4000  2000.0  2050.0  2122  2111

# %%
emp_salary_df = pd.DataFrame(empSalary,
                             columns=['Name', 'Jan', 'Feb', 'March', 'April', 'May'])

print('Dataframe Contents:')
print(emp_salary_df)
# Out:
# Dataframe Contents:
#     Name   Jan     Feb   March  April   May
# 0   jack  2000  2010.0  2050.0   2134  2111
# 1   Riti  3000  3022.0  3456.0   3111  2109
# 2   Aadi  4022     NaN  2077.0   2134  3122
# 3  Mohit  3012  3050.0  2010.0   2122  1111
# 4  Veena  2023  2232.0     NaN   2112  1099
# 5  Shaun  2123  2510.0  3050.0   3134  2122
# 6   Mark  4000  2000.0  2050.0   2122  2111

# %%
emp_salary_df.set_index('Name', inplace=True)
print('Dataframe Contents:')
print(emp_salary_df)
# Out:
# Dataframe Contents:
#         Jan     Feb   March  April   May
# Name
# jack   2000  2010.0  2050.0   2134  2111
# Riti   3000  3022.0  3456.0   3111  2109
# Aadi   4022     NaN  2077.0   2134  3122
# Mohit  3012  3050.0  2010.0   2122  1111
# Veena  2023  2232.0     NaN   2112  1099
# Shaun  2123  2510.0  3050.0   3134  2122
# Mark   4000  2000.0  2050.0   2122  2111

# %%
# Get the sum of values along the default axis i.e. index/rows
result = emp_salary_df.sum()
print('Series containing sum of values in each column:')
print(result)
# Out:
# Series containing sum of values in each column:
# Jan      20180.0
# Feb      14824.0
# March    14693.0
# April    16869.0
# May      13785.0
# dtype: float64

# %%
# Get the sum of values along the axis 1 i.e. columns
result = emp_salary_df.sum(axis=1)
print('Series containing sum of values in each row:')
print(result)
# Out:
# Series containing sum of values in each row:
# Name
# jack     10305.0
# Riti     14698.0
# Aadi     11355.0
# Mohit    11305.0
# Veena     7466.0
# Shaun    12939.0
# Mark     12283.0
# dtype: float64

# %%
# Get a Sum of values along default axis (index/rows)
# in dataframe without skipping NaNs
result = emp_salary_df.sum(skipna=False)
print('Series containing sum of values in each column:')
print(result)
# Out:
# Series containing sum of values in each column:
# Jan      20180.0
# Feb          NaN
# March        NaN
# April    16869.0
# May      13785.0
# dtype: float64

# %%
# Get sum of values in columns if min number
# of Non-NaN values are 7
result = emp_salary_df.sum(min_count=7)
print('Series containing sum of values in each column:')
print(result)
# Out:
# Series containing sum of values in each column:
# Jan      20180.0
# Feb          NaN
# March        NaN
# April    16869.0
# May      13785.0
# dtype: float64

# %%
# Get sum of values in columns if min number
# of Non-NaN values are 7
result = emp_salary_df.sum(min_count=1)
print('Series containing sum of values in each column:')
print(result)
# Out:
# Series containing sum of values in each column:
# Jan      20180.0
# Feb      14824.0
# March    14693.0
# April    16869.0
# May      13785.0
# dtype: float64

# %%
# List of Tuples
empSalary = [('jack',   'Delhi', 2000, 2010,    2050,   2134, 2111),
             ('Riti',   'Mumbai',3000, 3022,    3456,   3111, 2109),
             ('Aadi',   'Delhi', 4022, np.NaN,  2077,   2134, 3122),
             ('Mohit',  'Mumbai',3012, 3050,    2010,   2122, 1111),
             ('Veena',  'Delhi', 2023, 2232,    np.NaN, 2112, 1099),
             ('Shaun',  'Mumbai',2123, 2510,    3050,   3134, 2122),
             ('Mark',   'Mumbai',4000, 2000,    2050,   2122, 2111)
             ]
emp_salary_df = pd.DataFrame(empSalary, columns=['Name', 'City', 'Jan', 'Feb', 'March', 'April', 'May'])
emp_salary_df.set_index(['Name', 'City'], inplace=True)
print(emp_salary_df)
# Out:
#                Jan     Feb   March  April   May
# Name  City
# jack  Delhi   2000  2010.0  2050.0   2134  2111
# Riti  Mumbai  3000  3022.0  3456.0   3111  2109
# Aadi  Delhi   4022     NaN  2077.0   2134  3122
# Mohit Mumbai  3012  3050.0  2010.0   2122  1111
# Veena Delhi   2023  2232.0     NaN   2112  1099
# Shaun Mumbai  2123  2510.0  3050.0   3134  2122
# Mark  Mumbai  4000  2000.0  2050.0   2122  2111

# %%
# Get sum of values for a level 'City' only
df = emp_salary_df.groupby(level='City').sum()

print('Summed up values for level "City": ')
print(df)
# Out:
# Summed up values for level "City":
#           Jan      Feb    March  April   May
# City
# Delhi    8045   4242.0   4127.0   6380  6332
# Mumbai  12135  10582.0  10566.0  10489  7453

# %%
# Get sum of values for a level 'City' only
df = emp_salary_df.groupby(level='City').mean()

print('Summed up values for level "City": ')
print(df)
# Out:
# Summed up values for level "City":
#                 Jan     Feb   March        April          May
# City
# Delhi   2681.666667  2121.0  2063.5  2126.666667  2110.666667
# Mumbai  3033.750000  2645.5  2641.5  2622.250000  1863.250000

# %% [markdown]
# **Practice - wiil be evaluated in next lab**
#
# count
#
# describe
#
# min, max
#
# agrmin,argmax
#
# idxmin,idxmax
#
# quantile
#
# sum
#
# mean
#
# median
#
# mad
#
# prod
#
# var
#
# std
#
# skew
#
# kurt
#
# cumsum
#
# cummin,cummax
#
# cumprod
#
# diff
#
# pct_change

# %%
# import pandas as pd

# # Create a DataFrame
# df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 1, 6]})

# # Find the index label corresponding to the minimum value in column 'A'
# min_index = df['A'].idxmin()  #with dataframe and arg with series
# print("Index label with minimum value in column 'A':", min_index)
# Out:
# Index label with minimum value in column 'A': 0

# %%
import pandas as pd

# Create a DataFrame
df = pd.DataFrame({'A': [10, 15, 20, 25, 30]})

# Calculate the percentage change from the previous row
df['pct_change'] = df['A'].pct_change()

print(df)
# Out:
#     A  pct_change
# 0  10         NaN
# 1  15    0.500000
# 2  20    0.333333
# 3  25    0.250000
# 4  30    0.200000

# %%
# sns.get_dataset_names()

# %%
import seaborn as sns
planets=sns.load_dataset('planets')
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
planets['pct_change'] = planets['number'].pct_change()
planets.head()
# Out:
#             method  number  orbital_period   mass  distance  year  pct_change
# 0  Radial Velocity       1         269.300   7.10     77.40  2006         NaN
# 1  Radial Velocity       1         874.774   2.21     56.95  2008         0.0
# 2  Radial Velocity       1         763.000   2.60     19.84  2011         0.0
# 3  Radial Velocity       1         326.030  19.40    110.62  2007         0.0
# 4  Radial Velocity       1         516.220  10.50    119.47  2009         0.0

# %%
planets['orbital_period'].corr(planets['mass'])
# Out:
# 0.17372547058552631

# %%
planets['orbital_period'].cov(planets['mass'])
# Out:
# 1005.4725944465806

# %%
# rng=np.random.RandomState(42)
# ser=pd.Series(rng.rand(5))
# ser
# Out:
# 0    0.374540
# 1    0.950714
# 2    0.731994
# 3    0.598658
# 4    0.156019
# dtype: float64

# %%
# df=pd.DataFrame({'A':rng.rand(5),
#                 'B':rng.rand(5)})
# df
# Out:
#           A         B
# 0  0.155995  0.020584
# 1  0.058084  0.969910
# 2  0.866176  0.832443
# 3  0.601115  0.212339
# 4  0.708073  0.181825

# %%
planets.dropna().describe()
# Out:
#            number  orbital_period        mass    distance         year  \
# count  497.000000      497.000000  497.000000  497.000000   497.000000
# mean     1.736419      836.918467    2.500083   52.017243  2007.380282
# std      1.176441     1470.388062    3.634085   46.629091     4.171023
# min      1.000000        1.328300    0.003600    1.350000  1989.000000
# 25%      1.000000       38.021000    0.210000   24.150000  2005.000000
# 50%      1.000000      358.000000    1.240000   39.560000  2009.000000
# 75%      2.000000     1001.700000    2.830000   59.280000  2011.000000
# max      6.000000    17337.500000   25.000000  354.000000  2014.000000
#
#        pct_change
# count  497.000000
# mean     0.126626
# std      0.649837
# min     -0.833333
# 25%      0.000000
# 50%      0.000000
# 75%      0.000000
# max      5.000000

# %%
planets.describe()
# Out:
#             number  orbital_period        mass     distance         year  \
# count  1035.000000      992.000000  513.000000   808.000000  1035.000000
# mean      1.785507     2002.917596    2.638161   264.069282  2009.070531
# std       1.240976    26014.728304    3.818617   733.116493     3.972567
# min       1.000000        0.090706    0.003600     1.350000  1989.000000
# 25%       1.000000        5.442540    0.229000    32.560000  2007.000000
# 50%       1.000000       39.979500    1.260000    55.250000  2010.000000
# 75%       2.000000      526.005000    3.040000   178.500000  2012.000000
# max       7.000000   730000.000000   25.000000  8500.000000  2014.000000
#
#         pct_change
# count  1034.000000
# mean      0.090177
# std       0.547813
# min      -0.857143
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       5.000000

# %% [markdown]
# **Unique values, value counts and membership**

# %%
df = pd.DataFrame({'A': [1, 2, 3, 1, 2, 3],
                   'B': ['x', 'y', 'x', 'y', 'x', 'y']})
df
# Out:
#    A  B
# 0  1  x
# 1  2  y
# 2  3  x
# 3  1  y
# 4  2  x
# 5  3  y

# %%
# Unique values in column 'A'
unique_values_A = df['A'].unique()

# Value counts of column 'A'
value_counts_A = df['A'].value_counts()

# Membership check for values in column 'B'
membership_check_B = df['B'].isin(['x', 'z'])

# %%
print("Unique values in column 'A':", unique_values_A)
print("\nValue counts of column 'A':\n", value_counts_A)
print("\nMembership check for values in column 'B':\n", membership_check_B)
# Out:
# Unique values in column 'A': [1 2 3]
#
# Value counts of column 'A':
#  1    2
# 2    2
# 3    2
# Name: A, dtype: int64
#
# Membership check for values in column 'B':
#  0     True
# 1    False
# 2     True
# 3    False
# 4     True
# 5    False
# Name: B, dtype: bool

# %%
df = pd.DataFrame({'A': [1, 2, 3, 1, 2, 3,3],
                   'B': ['x', 'y', 'x', 'y', 'x', 'y','y']})

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
deduplicated_df = df.drop_duplicates()
print("\nDeduplicated DataFrame:\n", deduplicated_df)
# Out:
# Deduplicated DataFrame:
#     A  B
# 0  1  x
# 1  2  y
# 2  3  x
# 3  1  y
# 4  2  x
# 5  3  y

# %%
df = pd.DataFrame([[1, np.nan, 2],
                     [2, 3, 5],
                 [np.nan, 4, 6]])
df
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df.dropna() #Drop rows with any missing values
# Out:
#      0    1  2
# 1  2.0  3.0  5

# %%
df.dropna(axis='columns') #Drop columns with any missing values
# Out:
#    2
# 0  2
# 1  5
# 2  6

# %%
df.dropna(axis='columns',how='all') #Drop columns with all missing values
# Out:
#      0    1  2
# 0  1.0  NaN  2
# 1  2.0  3.0  5
# 2  NaN  4.0  6

# %%
df[3]=[1,2,3]
df
# Out:
#      0    1  2  3
# 0  1.0  NaN  2  1
# 1  2.0  3.0  5  2
# 2  NaN  4.0  6  3

# %%
df[4]=np.nan
df
# Out:
#      0    1  2  3   4
# 0  1.0  NaN  2  1 NaN
# 1  2.0  3.0  5  2 NaN
# 2  NaN  4.0  6  3 NaN

# %%
df.dropna(axis='rows',thresh=4) #minimum number of non-null values for the row/column to be kept:
# df.dropna(axis='columns',how='all')
# Out:
#      0    1  2  3   4
# 1  2.0  3.0  5  2 NaN

# %% [markdown]
# https://thispointer.com/pandas-dataframe-sum-method-tutorial-examples/
#
# https://www.kaggle.com/code/abhi8923shriv/pandas-library-80-exercises
